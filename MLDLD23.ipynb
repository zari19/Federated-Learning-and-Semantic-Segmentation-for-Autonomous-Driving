# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/DELIVERY
# Out:
# /content/drive/MyDrive/DELIVERY

# %%
import torch
device = torch.device( 'cuda' if torch. cuda. is_available () else 'cpu')

# %%
# !pip install wandb
# !pip install pytorch_lightning

# %%
# !python steps.py --dataset idda --model deeplabv3_mobilenetv2 --num_rounds 10 --num_epochs 5 --clients_per_round 2 --bs 2 --lr 0.01 --step 1 --domain same --modality 2
